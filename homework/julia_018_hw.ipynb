# %% [markdown]
# # DataFrames.jl 介紹 (二): Joins 與 Split-Apply-Combine Strategy
#
# ## Day 018 作業1：The Split-Apply-Combine Strategy
#
# 同 Day 017，請載入 2020/4/2 COVID-19 Daily Report 資料集，計算每個國家/地區的累計確診人數，並列出所有資料筆數。

# %%
using DataFrames, CSV

# %%
df = CSV.read("04-02-2020.csv")
# Out:
# 2569×12 DataFrame. Omitted printing of 8 columns
# │ Row  │ FIPS    │ Admin2     │ Province_State │ Country_Region       │
# │      │ Int64⍰  │ String⍰    │ String⍰        │ String               │
# ├──────┼─────────┼────────────┼────────────────┼──────────────────────┤
# │ 1    │ 45001   │ Abbeville  │ South Carolina │ US                   │
# │ 2    │ 22001   │ Acadia     │ Louisiana      │ US                   │
# │ 3    │ 51001   │ Accomack   │ Virginia       │ US                   │
# │ 4    │ 16001   │ Ada        │ Idaho          │ US                   │
# │ 5    │ 19001   │ Adair      │ Iowa           │ US                   │
# │ 6    │ 29001   │ Adair      │ Missouri       │ US                   │
# │ 7    │ 40001   │ Adair      │ Oklahoma       │ US                   │
# │ 8    │ 8001    │ Adams      │ Colorado       │ US                   │
# │ 9    │ 16003   │ Adams      │ Idaho          │ US                   │
# │ 10   │ 17001   │ Adams      │ Illinois       │ US                   │
# ⋮
# │ 2559 │ missing │ missing    │ missing        │ Ukraine              │
# │ 2560 │ missing │ missing    │ missing        │ United Arab Emirates │
# │ 2561 │ missing │ missing    │ missing        │ United Kingdom       │
# │ 2562 │ missing │ missing    │ missing        │ Uruguay              │
# │ 2563 │ missing │ missing    │ missing        │ Uzbekistan           │
# │ 2564 │ missing │ missing    │ missing        │ Venezuela            │
# │ 2565 │ missing │ missing    │ missing        │ Vietnam              │
# │ 2566 │ missing │ missing    │ missing        │ West Bank and Gaza   │
# │ 2567 │ missing │ missing    │ missing        │ Zambia               │
# │ 2568 │ missing │ missing    │ missing        │ Zimbabwe             │
# │ 2569 │ missing │ unassigned │ Wyoming        │ US                   │

# %% [markdown]
# 計算計算每個國家/地區的累計確診人數
#
# 【提示】可使用 groupby 相關的函式

# %%
show(df[1:3, :], allcols = true)
# Out:
# 3×12 DataFrame
# │ Row │ FIPS   │ Admin2    │ Province_State │ Country_Region │
# │     │ Int64⍰ │ String⍰   │ String⍰        │ String         │
# ├─────┼────────┼───────────┼────────────────┼────────────────┤
# │ 1   │ 45001  │ Abbeville │ South Carolina │ US             │
# │ 2   │ 22001  │ Acadia    │ Louisiana      │ US             │
# │ 3   │ 51001  │ Accomack  │ Virginia       │ US             │
#
# │ Row │ Last_Update         │ Lat      │ Long_    │ Confirmed │ Deaths │
# │     │ String              │ Float64⍰ │ Float64⍰ │ Int64     │ Int64  │
# ├─────┼─────────────────────┼──────────┼──────────┼───────────┼────────┤
# │ 1   │ 2020-04-02 23:25:27 │ 34.2233  │ -82.4617 │ 6         │ 0      │
# │ 2   │ 2020-04-02 23:25:27 │ 30.2951  │ -92.4142 │ 61        │ 1      │
# │ 3   │ 2020-04-02 23:25:27 │ 37.7671  │ -75.6323 │ 10        │ 0      │
#
# │ Row │ Recovered │ Active │ Combined_Key                  │
# │     │ Int64     │ Int64  │ String                        │
# ├─────┼───────────┼────────┼───────────────────────────────┤
# │ 1   │ 0         │ 0      │ Abbeville, South Carolina, US │
# │ 2   │ 0         │ 0      │ Acadia, Louisiana, US         │
# │ 3   │ 0         │ 0      │ Accomack, Virginia, US        │

# %%
df2 = by(df, [:Country_Region, :Province_State], :Confirmed => sum)
# Out:
# 315×3 DataFrame
# │ Row │ Country_Region       │ Province_State │ Confirmed_sum │
# │     │ String               │ String⍰        │ Int64         │
# ├─────┼──────────────────────┼────────────────┼───────────────┤
# │ 1   │ US                   │ South Carolina │ 1554          │
# │ 2   │ US                   │ Louisiana      │ 9159          │
# │ 3   │ US                   │ Virginia       │ 1706          │
# │ 4   │ US                   │ Idaho          │ 776           │
# │ 5   │ US                   │ Iowa           │ 614           │
# │ 6   │ US                   │ Missouri       │ 1857          │
# │ 7   │ US                   │ Oklahoma       │ 881           │
# │ 8   │ US                   │ Colorado       │ 3342          │
# │ 9   │ US                   │ Illinois       │ 7695          │
# │ 10  │ US                   │ Indiana        │ 3038          │
# ⋮
# │ 305 │ Uganda               │ missing        │ 45            │
# │ 306 │ Ukraine              │ missing        │ 897           │
# │ 307 │ United Arab Emirates │ missing        │ 1024          │
# │ 308 │ United Kingdom       │ missing        │ 33718         │
# │ 309 │ Uruguay              │ missing        │ 350           │
# │ 310 │ Uzbekistan           │ missing        │ 205           │
# │ 311 │ Venezuela            │ missing        │ 146           │
# │ 312 │ Vietnam              │ missing        │ 233           │
# │ 313 │ West Bank and Gaza   │ missing        │ 161           │
# │ 314 │ Zambia               │ missing        │ 39            │
# │ 315 │ Zimbabwe             │ missing        │ 9             │

# %%
# 顯示所有資料
show(df2, allcols=true, allrows=true)
# Out:
# 315×3 DataFrame
# │ Row │ Country_Region                   │ Province_State                   │
# │     │ String                           │ Union{Missing, String}           │
# ├─────┼──────────────────────────────────┼──────────────────────────────────┤
# │ 1   │ US                               │ South Carolina                   │
# │ 2   │ US                               │ Louisiana                        │
# │ 3   │ US                               │ Virginia                         │
# │ 4   │ US                               │ Idaho                            │
# │ 5   │ US                               │ Iowa                             │
# │ 6   │ US                               │ Missouri                         │
# │ 7   │ US                               │ Oklahoma                         │
# │ 8   │ US                               │ Colorado                         │
# │ 9   │ US                               │ Illinois                         │
# │ 10  │ US                               │ Indiana                          │
# │ 11  │ US                               │ Mississippi                      │
# │ 12  │ US                               │ Nebraska                         │
# │ 13  │ US                               │ Pennsylvania                     │
# │ 14  │ US                               │ Washington                       │
# │ 15  │ US                               │ Wisconsin                        │
# │ 16  │ US                               │ Vermont                          │
# │ 17  │ US                               │ Florida                          │
# │ 18  │ US                               │ North Carolina                   │
# │ 19  │ US                               │ California                       │
# │ 20  │ US                               │ New York                         │
# │ 21  │ US                               │ Wyoming                          │
# │ 22  │ US                               │ Michigan                         │
# │ 23  │ US                               │ Maryland                         │
# │ 24  │ US                               │ Kentucky                         │
# │ 25  │ US                               │ Ohio                             │
# │ 26  │ US                               │ Alaska                           │
# │ 27  │ US                               │ Kansas                           │
# │ 28  │ US                               │ Tennessee                        │
# │ 29  │ US                               │ Texas                            │
# │ 30  │ US                               │ Maine                            │
# │ 31  │ US                               │ Minnesota                        │
# │ 32  │ US                               │ Arizona                          │
# │ 33  │ US                               │ Georgia                          │
# │ 34  │ US                               │ Arkansas                         │
# │ 35  │ US                               │ New Jersey                       │
# │ 36  │ US                               │ South Dakota                     │
# │ 37  │ US                               │ Alabama                          │
# │ 38  │ US                               │ West Virginia                    │
# │ 39  │ US                               │ North Dakota                     │
# │ 40  │ US                               │ Massachusetts                    │
# │ 41  │ US                               │ New Hampshire                    │
# │ 42  │ US                               │ Oregon                           │
# │ 43  │ US                               │ New Mexico                       │
# │ 44  │ US                               │ Utah                             │
# │ 45  │ US                               │ Rhode Island                     │
# │ 46  │ US                               │ Montana                          │
# │ 47  │ US                               │ Nevada                           │
# │ 48  │ US                               │ District of Columbia             │
# │ 49  │ US                               │ Connecticut                      │
# │ 50  │ US                               │ Hawaii                           │
# │ 51  │ US                               │ Delaware                         │
# │ 52  │ Canada                           │ Alberta                          │
# │ 53  │ United Kingdom                   │ Anguilla                         │
# │ 54  │ China                            │ Anhui                            │
# │ 55  │ Netherlands                      │ Aruba                            │
# │ 56  │ Australia                        │ Australian Capital Territory     │
# │ 57  │ China                            │ Beijing                          │
# │ 58  │ United Kingdom                   │ Bermuda                          │
# │ 59  │ Netherlands                      │ Bonaire, Sint Eustatius and Saba │
# │ 60  │ Canada                           │ British Columbia                 │
# │ 61  │ United Kingdom                   │ British Virgin Islands           │
# │ 62  │ United Kingdom                   │ Cayman Islands                   │
# │ 63  │ United Kingdom                   │ Channel Islands                  │
# │ 64  │ China                            │ Chongqing                        │
# │ 65  │ Netherlands                      │ Curacao                          │
# │ 66  │ Canada                           │ Diamond Princess                 │
# │ 67  │ US                               │ Diamond Princess                 │
# │ 68  │ Denmark                          │ Faroe Islands                    │
# │ 69  │ France                           │ French Guiana                    │
# │ 70  │ France                           │ French Polynesia                 │
# │ 71  │ China                            │ Fujian                           │
# │ 72  │ China                            │ Gansu                            │
# │ 73  │ United Kingdom                   │ Gibraltar                        │
# │ 74  │ Canada                           │ Grand Princess                   │
# │ 75  │ US                               │ Grand Princess                   │
# │ 76  │ Denmark                          │ Greenland                        │
# │ 77  │ France                           │ Guadeloupe                       │
# │ 78  │ US                               │ Guam                             │
# │ 79  │ China                            │ Guangdong                        │
# │ 80  │ China                            │ Guangxi                          │
# │ 81  │ China                            │ Guizhou                          │
# │ 82  │ China                            │ Hainan                           │
# │ 83  │ China                            │ Hebei                            │
# │ 84  │ China                            │ Heilongjiang                     │
# │ 85  │ China                            │ Henan                            │
# │ 86  │ China                            │ Hong Kong                        │
# │ 87  │ China                            │ Hubei                            │
# │ 88  │ China                            │ Hunan                            │
# │ 89  │ China                            │ Inner Mongolia                   │
# │ 90  │ United Kingdom                   │ Isle of Man                      │
# │ 91  │ China                            │ Jiangsu                          │
# │ 92  │ China                            │ Jiangxi                          │
# │ 93  │ China                            │ Jilin                            │
# │ 94  │ China                            │ Liaoning                         │
# │ 95  │ China                            │ Macau                            │
# │ 96  │ Canada                           │ Manitoba                         │
# │ 97  │ France                           │ Martinique                       │
# │ 98  │ France                           │ Mayotte                          │
# │ 99  │ United Kingdom                   │ Montserrat                       │
# │ 100 │ Canada                           │ New Brunswick                    │
# │ 101 │ France                           │ New Caledonia                    │
# │ 102 │ Australia                        │ New South Wales                  │
# │ 103 │ Canada                           │ Newfoundland and Labrador        │
# │ 104 │ China                            │ Ningxia                          │
# │ 105 │ US                               │ Northern Mariana Islands         │
# │ 106 │ Australia                        │ Northern Territory               │
# │ 107 │ Canada                           │ Northwest Territories            │
# │ 108 │ Canada                           │ Nova Scotia                      │
# │ 109 │ Canada                           │ Ontario                          │
# │ 110 │ Canada                           │ Prince Edward Island             │
# │ 111 │ US                               │ Puerto Rico                      │
# │ 112 │ China                            │ Qinghai                          │
# │ 113 │ Canada                           │ Quebec                           │
# │ 114 │ Australia                        │ Queensland                       │
# │ 115 │ Canada                           │ Recovered                        │
# │ 116 │ US                               │ Recovered                        │
# │ 117 │ France                           │ Reunion                          │
# │ 118 │ France                           │ Saint Barthelemy                 │
# │ 119 │ Canada                           │ Saskatchewan                     │
# │ 120 │ China                            │ Shaanxi                          │
# │ 121 │ China                            │ Shandong                         │
# │ 122 │ China                            │ Shanghai                         │
# │ 123 │ China                            │ Shanxi                           │
# │ 124 │ China                            │ Sichuan                          │
# │ 125 │ Netherlands                      │ Sint Maarten                     │
# │ 126 │ Australia                        │ South Australia                  │
# │ 127 │ France                           │ St Martin                        │
# │ 128 │ Australia                        │ Tasmania                         │
# │ 129 │ China                            │ Tianjin                          │
# │ 130 │ China                            │ Tibet                            │
# │ 131 │ United Kingdom                   │ Turks and Caicos Islands         │
# │ 132 │ Australia                        │ Victoria                         │
# │ 133 │ US                               │ Virgin Islands                   │
# │ 134 │ Australia                        │ Western Australia                │
# │ 135 │ China                            │ Xinjiang                         │
# │ 136 │ Canada                           │ Yukon                            │
# │ 137 │ China                            │ Yunnan                           │
# │ 138 │ China                            │ Zhejiang                         │
# │ 139 │ Afghanistan                      │ missing                          │
# │ 140 │ Albania                          │ missing                          │
# │ 141 │ Algeria                          │ missing                          │
# │ 142 │ Andorra                          │ missing                          │
# │ 143 │ Angola                           │ missing                          │
# │ 144 │ Antigua and Barbuda              │ missing                          │
# │ 145 │ Argentina                        │ missing                          │
# │ 146 │ Armenia                          │ missing                          │
# │ 147 │ Austria                          │ missing                          │
# │ 148 │ Azerbaijan                       │ missing                          │
# │ 149 │ Bahamas                          │ missing                          │
# │ 150 │ Bahrain                          │ missing                          │
# │ 151 │ Bangladesh                       │ missing                          │
# │ 152 │ Barbados                         │ missing                          │
# │ 153 │ Belarus                          │ missing                          │
# │ 154 │ Belgium                          │ missing                          │
# │ 155 │ Belize                           │ missing                          │
# │ 156 │ Benin                            │ missing                          │
# │ 157 │ Bhutan                           │ missing                          │
# │ 158 │ Bolivia                          │ missing                          │
# │ 159 │ Bosnia and Herzegovina           │ missing                          │
# │ 160 │ Botswana                         │ missing                          │
# │ 161 │ Brazil                           │ missing                          │
# │ 162 │ Brunei                           │ missing                          │
# │ 163 │ Bulgaria                         │ missing                          │
# │ 164 │ Burkina Faso                     │ missing                          │
# │ 165 │ Burma                            │ missing                          │
# │ 166 │ Burundi                          │ missing                          │
# │ 167 │ Cabo Verde                       │ missing                          │
# │ 168 │ Cambodia                         │ missing                          │
# │ 169 │ Cameroon                         │ missing                          │
# │ 170 │ Central African Republic         │ missing                          │
# │ 171 │ Chad                             │ missing                          │
# │ 172 │ Chile                            │ missing                          │
# │ 173 │ Colombia                         │ missing                          │
# │ 174 │ Congo (Brazzaville)              │ missing                          │
# │ 175 │ Congo (Kinshasa)                 │ missing                          │
# │ 176 │ Costa Rica                       │ missing                          │
# │ 177 │ Cote d'Ivoire                    │ missing                          │
# │ 178 │ Croatia                          │ missing                          │
# │ 179 │ Cuba                             │ missing                          │
# │ 180 │ Cyprus                           │ missing                          │
# │ 181 │ Czechia                          │ missing                          │
# │ 182 │ Denmark                          │ missing                          │
# │ 183 │ Diamond Princess                 │ missing                          │
# │ 184 │ Djibouti                         │ missing                          │
# │ 185 │ Dominica                         │ missing                          │
# │ 186 │ Dominican Republic               │ missing                          │
# │ 187 │ Ecuador                          │ missing                          │
# │ 188 │ Egypt                            │ missing                          │
# │ 189 │ El Salvador                      │ missing                          │
# │ 190 │ Equatorial Guinea                │ missing                          │
# │ 191 │ Eritrea                          │ missing                          │
# │ 192 │ Estonia                          │ missing                          │
# │ 193 │ Eswatini                         │ missing                          │
# │ 194 │ Ethiopia                         │ missing                          │
# │ 195 │ Fiji                             │ missing                          │
# │ 196 │ Finland                          │ missing                          │
# │ 197 │ France                           │ missing                          │
# │ 198 │ Gabon                            │ missing                          │
# │ 199 │ Gambia                           │ missing                          │
# │ 200 │ Georgia                          │ missing                          │
# │ 201 │ Germany                          │ missing                          │
# │ 202 │ Ghana                            │ missing                          │
# │ 203 │ Greece                           │ missing                          │
# │ 204 │ Grenada                          │ missing                          │
# │ 205 │ Guatemala                        │ missing                          │
# │ 206 │ Guinea                           │ missing                          │
# │ 207 │ Guinea-Bissau                    │ missing                          │
# │ 208 │ Guyana                           │ missing                          │
# │ 209 │ Haiti                            │ missing                          │
# │ 210 │ Holy See                         │ missing                          │
# │ 211 │ Honduras                         │ missing                          │
# │ 212 │ Hungary                          │ missing                          │
# │ 213 │ Iceland                          │ missing                          │
# │ 214 │ India                            │ missing                          │
# │ 215 │ Indonesia                        │ missing                          │
# │ 216 │ Iran                             │ missing                          │
# │ 217 │ Iraq                             │ missing                          │
# │ 218 │ Ireland                          │ missing                          │
# │ 219 │ Israel                           │ missing                          │
# │ 220 │ Italy                            │ missing                          │
# │ 221 │ Jamaica                          │ missing                          │
# │ 222 │ Japan                            │ missing                          │
# │ 223 │ Jordan                           │ missing                          │
# │ 224 │ Kazakhstan                       │ missing                          │
# │ 225 │ Kenya                            │ missing                          │
# │ 226 │ Korea, South                     │ missing                          │
# │ 227 │ Kosovo                           │ missing                          │
# │ 228 │ Kuwait                           │ missing                          │
# │ 229 │ Kyrgyzstan                       │ missing                          │
# │ 230 │ Laos                             │ missing                          │
# │ 231 │ Latvia                           │ missing                          │
# │ 232 │ Lebanon                          │ missing                          │
# │ 233 │ Liberia                          │ missing                          │
# │ 234 │ Libya                            │ missing                          │
# │ 235 │ Liechtenstein                    │ missing                          │
# │ 236 │ Lithuania                        │ missing                          │
# │ 237 │ Luxembourg                       │ missing                          │
# │ 238 │ MS Zaandam                       │ missing                          │
# │ 239 │ Madagascar                       │ missing                          │
# │ 240 │ Malawi                           │ missing                          │
# │ 241 │ Malaysia                         │ missing                          │
# │ 242 │ Maldives                         │ missing                          │
# │ 243 │ Mali                             │ missing                          │
# │ 244 │ Malta                            │ missing                          │
# │ 245 │ Mauritania                       │ missing                          │
# │ 246 │ Mauritius                        │ missing                          │
# │ 247 │ Mexico                           │ missing                          │
# │ 248 │ Moldova                          │ missing                          │
# │ 249 │ Monaco                           │ missing                          │
# │ 250 │ Mongolia                         │ missing                          │
# │ 251 │ Montenegro                       │ missing                          │
# │ 252 │ Morocco                          │ missing                          │
# │ 253 │ Mozambique                       │ missing                          │
# │ 254 │ Namibia                          │ missing                          │
# │ 255 │ Nepal                            │ missing                          │
# │ 256 │ Netherlands                      │ missing                          │
# │ 257 │ New Zealand                      │ missing                          │
# │ 258 │ Nicaragua                        │ missing                          │
# │ 259 │ Niger                            │ missing                          │
# │ 260 │ Nigeria                          │ missing                          │
# │ 261 │ North Macedonia                  │ missing                          │
# │ 262 │ Norway                           │ missing                          │
# │ 263 │ Oman                             │ missing                          │
# │ 264 │ Pakistan                         │ missing                          │
# │ 265 │ Panama                           │ missing                          │
# │ 266 │ Papua New Guinea                 │ missing                          │
# │ 267 │ Paraguay                         │ missing                          │
# │ 268 │ Peru                             │ missing                          │
# │ 269 │ Philippines                      │ missing                          │
# │ 270 │ Poland                           │ missing                          │
# │ 271 │ Portugal                         │ missing                          │
# │ 272 │ Qatar                            │ missing                          │
# │ 273 │ Romania                          │ missing                          │
# │ 274 │ Russia                           │ missing                          │
# │ 275 │ Rwanda                           │ missing                          │
# │ 276 │ Saint Kitts and Nevis            │ missing                          │
# │ 277 │ Saint Lucia                      │ missing                          │
# │ 278 │ Saint Vincent and the Grenadines │ missing                          │
# │ 279 │ San Marino                       │ missing                          │
# │ 280 │ Saudi Arabia                     │ missing                          │
# │ 281 │ Senegal                          │ missing                          │
# │ 282 │ Serbia                           │ missing                          │
# │ 283 │ Seychelles                       │ missing                          │
# │ 284 │ Sierra Leone                     │ missing                          │
# │ 285 │ Singapore                        │ missing                          │
# │ 286 │ Slovakia                         │ missing                          │
# │ 287 │ Slovenia                         │ missing                          │
# │ 288 │ Somalia                          │ missing                          │
# │ 289 │ South Africa                     │ missing                          │
# │ 290 │ Spain                            │ missing                          │
# │ 291 │ Sri Lanka                        │ missing                          │
# │ 292 │ Sudan                            │ missing                          │
# │ 293 │ Suriname                         │ missing                          │
# │ 294 │ Sweden                           │ missing                          │
# │ 295 │ Switzerland                      │ missing                          │
# │ 296 │ Syria                            │ missing                          │
# │ 297 │ Taiwan*                          │ missing                          │
# │ 298 │ Tanzania                         │ missing                          │
# │ 299 │ Thailand                         │ missing                          │
# │ 300 │ Timor-Leste                      │ missing                          │
# │ 301 │ Togo                             │ missing                          │
# │ 302 │ Trinidad and Tobago              │ missing                          │
# │ 303 │ Tunisia                          │ missing                          │
# │ 304 │ Turkey                           │ missing                          │
# │ 305 │ Uganda                           │ missing                          │
# │ 306 │ Ukraine                          │ missing                          │
# │ 307 │ United Arab Emirates             │ missing                          │
# │ 308 │ United Kingdom                   │ missing                          │
# │ 309 │ Uruguay                          │ missing                          │
# │ 310 │ Uzbekistan                       │ missing                          │
# │ 311 │ Venezuela                        │ missing                          │
# │ 312 │ Vietnam                          │ missing                          │
# │ 313 │ West Bank and Gaza               │ missing                          │
# │ 314 │ Zambia                           │ missing                          │
# │ 315 │ Zimbabwe                         │ missing                          │
#
# │ Row │ Confirmed_sum │
# │     │ Int64         │
# ├─────┼───────────────┤
# │ 1   │ 1554          │
# │ 2   │ 9159          │
# │ 3   │ 1706          │
# │ 4   │ 776           │
# │ 5   │ 614           │
# │ 6   │ 1857          │
# │ 7   │ 881           │
# │ 8   │ 3342          │
# │ 9   │ 7695          │
# │ 10  │ 3038          │
# │ 11  │ 1177          │
# │ 12  │ 246           │
# │ 13  │ 7268          │
# │ 14  │ 6389          │
# │ 15  │ 1748          │
# │ 16  │ 338           │
# │ 17  │ 9008          │
# │ 18  │ 1977          │
# │ 19  │ 10773         │
# │ 20  │ 92506         │
# │ 21  │ 150           │
# │ 22  │ 10791         │
# │ 23  │ 2331          │
# │ 24  │ 770           │
# │ 25  │ 2901          │
# │ 26  │ 143           │
# │ 27  │ 553           │
# │ 28  │ 2845          │
# │ 29  │ 5069          │
# │ 30  │ 376           │
# │ 31  │ 742           │
# │ 32  │ 1715          │
# │ 33  │ 5348          │
# │ 34  │ 643           │
# │ 35  │ 25590         │
# │ 36  │ 165           │
# │ 37  │ 1233          │
# │ 38  │ 216           │
# │ 39  │ 159           │
# │ 40  │ 8966          │
# │ 41  │ 316           │
# │ 42  │ 826           │
# │ 43  │ 388           │
# │ 44  │ 1092          │
# │ 45  │ 657           │
# │ 46  │ 241           │
# │ 47  │ 1463          │
# │ 48  │ 653           │
# │ 49  │ 3824          │
# │ 50  │ 256           │
# │ 51  │ 393           │
# │ 52  │ 969           │
# │ 53  │ 3             │
# │ 54  │ 990           │
# │ 55  │ 60            │
# │ 56  │ 87            │
# │ 57  │ 582           │
# │ 58  │ 35            │
# │ 59  │ 2             │
# │ 60  │ 1121          │
# │ 61  │ 3             │
# │ 62  │ 28            │
# │ 63  │ 193           │
# │ 64  │ 579           │
# │ 65  │ 11            │
# │ 66  │ 0             │
# │ 67  │ 49            │
# │ 68  │ 177           │
# │ 69  │ 51            │
# │ 70  │ 37            │
# │ 71  │ 345           │
# │ 72  │ 138           │
# │ 73  │ 88            │
# │ 74  │ 13            │
# │ 75  │ 103           │
# │ 76  │ 10            │
# │ 77  │ 128           │
# │ 78  │ 82            │
# │ 79  │ 1507          │
# │ 80  │ 254           │
# │ 81  │ 146           │
# │ 82  │ 168           │
# │ 83  │ 325           │
# │ 84  │ 488           │
# │ 85  │ 1276          │
# │ 86  │ 802           │
# │ 87  │ 67802         │
# │ 88  │ 1019          │
# │ 89  │ 117           │
# │ 90  │ 95            │
# │ 91  │ 647           │
# │ 92  │ 937           │
# │ 93  │ 98            │
# │ 94  │ 141           │
# │ 95  │ 41            │
# │ 96  │ 167           │
# │ 97  │ 138           │
# │ 98  │ 116           │
# │ 99  │ 5             │
# │ 100 │ 91            │
# │ 101 │ 18            │
# │ 102 │ 2298          │
# │ 103 │ 183           │
# │ 104 │ 75            │
# │ 105 │ 6             │
# │ 106 │ 21            │
# │ 107 │ 2             │
# │ 108 │ 193           │
# │ 109 │ 2793          │
# │ 110 │ 22            │
# │ 111 │ 316           │
# │ 112 │ 18            │
# │ 113 │ 5518          │
# │ 114 │ 835           │
# │ 115 │ 0             │
# │ 116 │ 0             │
# │ 117 │ 308           │
# │ 118 │ 6             │
# │ 119 │ 206           │
# │ 120 │ 255           │
# │ 121 │ 775           │
# │ 122 │ 522           │
# │ 123 │ 137           │
# │ 124 │ 554           │
# │ 125 │ 18            │
# │ 126 │ 367           │
# │ 127 │ 22            │
# │ 128 │ 72            │
# │ 129 │ 176           │
# │ 130 │ 1             │
# │ 131 │ 5             │
# │ 132 │ 1036          │
# │ 133 │ 30            │
# │ 134 │ 400           │
# │ 135 │ 76            │
# │ 136 │ 6             │
# │ 137 │ 183           │
# │ 138 │ 1258          │
# │ 139 │ 273           │
# │ 140 │ 277           │
# │ 141 │ 986           │
# │ 142 │ 428           │
# │ 143 │ 8             │
# │ 144 │ 9             │
# │ 145 │ 1133          │
# │ 146 │ 663           │
# │ 147 │ 11129         │
# │ 148 │ 400           │
# │ 149 │ 24            │
# │ 150 │ 643           │
# │ 151 │ 56            │
# │ 152 │ 46            │
# │ 153 │ 304           │
# │ 154 │ 15348         │
# │ 155 │ 3             │
# │ 156 │ 13            │
# │ 157 │ 5             │
# │ 158 │ 123           │
# │ 159 │ 533           │
# │ 160 │ 4             │
# │ 161 │ 8044          │
# │ 162 │ 133           │
# │ 163 │ 457           │
# │ 164 │ 288           │
# │ 165 │ 20            │
# │ 166 │ 3             │
# │ 167 │ 6             │
# │ 168 │ 110           │
# │ 169 │ 306           │
# │ 170 │ 3             │
# │ 171 │ 8             │
# │ 172 │ 3404          │
# │ 173 │ 1161          │
# │ 174 │ 22            │
# │ 175 │ 134           │
# │ 176 │ 396           │
# │ 177 │ 194           │
# │ 178 │ 1011          │
# │ 179 │ 233           │
# │ 180 │ 356           │
# │ 181 │ 3858          │
# │ 182 │ 3386          │
# │ 183 │ 712           │
# │ 184 │ 40            │
# │ 185 │ 12            │
# │ 186 │ 1380          │
# │ 187 │ 3163          │
# │ 188 │ 865           │
# │ 189 │ 41            │
# │ 190 │ 15            │
# │ 191 │ 22            │
# │ 192 │ 858           │
# │ 193 │ 9             │
# │ 194 │ 29            │
# │ 195 │ 7             │
# │ 196 │ 1518          │
# │ 197 │ 59105         │
# │ 198 │ 21            │
# │ 199 │ 4             │
# │ 200 │ 134           │
# │ 201 │ 84794         │
# │ 202 │ 204           │
# │ 203 │ 1544          │
# │ 204 │ 10            │
# │ 205 │ 47            │
# │ 206 │ 52            │
# │ 207 │ 9             │
# │ 208 │ 19            │
# │ 209 │ 16            │
# │ 210 │ 7             │
# │ 211 │ 219           │
# │ 212 │ 585           │
# │ 213 │ 1319          │
# │ 214 │ 2543          │
# │ 215 │ 1790          │
# │ 216 │ 50468         │
# │ 217 │ 772           │
# │ 218 │ 3849          │
# │ 219 │ 6857          │
# │ 220 │ 115242        │
# │ 221 │ 47            │
# │ 222 │ 2495          │
# │ 223 │ 299           │
# │ 224 │ 435           │
# │ 225 │ 110           │
# │ 226 │ 9976          │
# │ 227 │ 125           │
# │ 228 │ 342           │
# │ 229 │ 116           │
# │ 230 │ 10            │
# │ 231 │ 458           │
# │ 232 │ 494           │
# │ 233 │ 6             │
# │ 234 │ 11            │
# │ 235 │ 75            │
# │ 236 │ 649           │
# │ 237 │ 2487          │
# │ 238 │ 9             │
# │ 239 │ 59            │
# │ 240 │ 3             │
# │ 241 │ 3116          │
# │ 242 │ 19            │
# │ 243 │ 36            │
# │ 244 │ 196           │
# │ 245 │ 6             │
# │ 246 │ 169           │
# │ 247 │ 1378          │
# │ 248 │ 505           │
# │ 249 │ 60            │
# │ 250 │ 14            │
# │ 251 │ 144           │
# │ 252 │ 708           │
# │ 253 │ 10            │
# │ 254 │ 14            │
# │ 255 │ 6             │
# │ 256 │ 14697         │
# │ 257 │ 797           │
# │ 258 │ 5             │
# │ 259 │ 98            │
# │ 260 │ 184           │
# │ 261 │ 384           │
# │ 262 │ 5147          │
# │ 263 │ 231           │
# │ 264 │ 2421          │
# │ 265 │ 1317          │
# │ 266 │ 1             │
# │ 267 │ 77            │
# │ 268 │ 1414          │
# │ 269 │ 2633          │
# │ 270 │ 2946          │
# │ 271 │ 9034          │
# │ 272 │ 949           │
# │ 273 │ 2738          │
# │ 274 │ 3548          │
# │ 275 │ 84            │
# │ 276 │ 9             │
# │ 277 │ 13            │
# │ 278 │ 2             │
# │ 279 │ 245           │
# │ 280 │ 1885          │
# │ 281 │ 195           │
# │ 282 │ 1171          │
# │ 283 │ 10            │
# │ 284 │ 2             │
# │ 285 │ 1049          │
# │ 286 │ 426           │
# │ 287 │ 897           │
# │ 288 │ 5             │
# │ 289 │ 1462          │
# │ 290 │ 112065        │
# │ 291 │ 151           │
# │ 292 │ 8             │
# │ 293 │ 10            │
# │ 294 │ 5568          │
# │ 295 │ 18827         │
# │ 296 │ 16            │
# │ 297 │ 339           │
# │ 298 │ 20            │
# │ 299 │ 1875          │
# │ 300 │ 1             │
# │ 301 │ 39            │
# │ 302 │ 94            │
# │ 303 │ 455           │
# │ 304 │ 18135         │
# │ 305 │ 45            │
# │ 306 │ 897           │
# │ 307 │ 1024          │
# │ 308 │ 33718         │
# │ 309 │ 350           │
# │ 310 │ 205           │
# │ 311 │ 146           │
# │ 312 │ 233           │
# │ 313 │ 161           │
# │ 314 │ 39            │
# │ 315 │ 9             │

# %% [markdown]
# ## 作業2：請列出美國各區域或事件 (依 Province_State 欄) 的累積確診、死亡、康復人數。
#
# 【提示】使用 Split-Apply-Combine Strategy 時，有幾種不同的函式可以使用，請參照 `DataFrames.jl` 官方文件 [https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby](https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby)
